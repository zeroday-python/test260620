# %%
d = {"name": "홍길동"}
print(d)

d = {100: "학생"}
print(d)

d = {
    (1, 2): "좌표"
}
print(d)

d = {
    [1, 2]: "리스트"
} # error
print(d)
# Out:
# {'name': '홍길동'}
# {100: '학생'}
# {(1, 2): '좌표'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       7 d = {
#       8     (1, 2): "좌표"
#       9 }
#      10 print(d)
# ---> 12 d = {
#      13     [1, 2]: "리스트"
#      14 } # error
#      15 print(d)
#
# TypeError: unhashable type: 'list'
